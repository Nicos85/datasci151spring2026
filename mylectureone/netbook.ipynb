# %% [markdown]
# These are where lecture notes will be written, describing what is happening in the code cells

# %% [markdown]
# There are different ways of changing fonts...
#
# <font size = "4">
#
# font size 4
#
#
# # big text
#
# ## slightly smaller text

# %%
print("Hello World")
# Out:
# Hello World
